# %%
#!/usr/bin/env python
# -*- coding: utf-8 -*-

import os
import logging
import time
import requests
from bs4 import BeautifulSoup
import time
import random
import re

# %%
# init logging
# posix stands for UNIX-systems
if os.name == 'posix':
    # coloring on linux
    cyellow = '\033[93m'
    cblue = '\033[94m'
    coff = '\033[0m'
    format = '[' + cblue + '%(asctime)s' + coff + '|' + cblue + '%(filename)-18s' + coff + '|' + cyellow + \
             '%(levelname)-8s' + coff + ']: %(message)s'
else:
    # else without color
    format = '[%(asctime)s|%(filename)-18s|%(levelname)-8s]: %(message)s',
    logging.basicConfig(
    filename='log.txt',
    format=format,
    filemode='w',
    datefmt='%Y/%m/%d %H:%M:%S',
    level=logging.DEBUG)
    __log__ = logging.getLogger(__name__)

# %% [markdown]
#  # Helper functions

# %%
def process_string(string):
    # Remove new line characters
    string = string.replace("\n", "")
    # Replace multiple whitespaces with a single one
    string = " ".join(string.split())
    # Remove following and starting whitespaces
    string = string.strip()
    return string

def extract_urls(string):
    urls =  re.findall(r'(http|ftp|https):\/\/([\w\-_]+(?:(?:\.[\w\-_]+)+))([\w\-\.,@?^=%&:/~\+#]*[\w\-\@?^=%&/~\+#])?' , string)
    return urls

def change_url_after_last_slash(url, new_end):
    """
    new_end needs to contain a starting "/"
    """
    return url[:url.rfind("/")] + new_end

def count_announcements(soup):
    return len(soup.find_all("h3"))

def get_announcements_from_page(soup):
    flat_list = list()
    announcements = soup.find_all("h3")
    # The first and the last h3 objects are no announcements
    for i in range(1, len(announcements) - 1):
        title = process_string(announcements[i].text)
        relative_link = announcements[i].find("a").get("href")
        link = change_url_after_last_slash(url, relative_link)
        # print(f"Flat title: {title}")
        # print(f"Flat link : {link}")
        # print("")
        flat_list.append([title, link])
    return flat_list 

def iterate_through_pages(url, max_no = 1000):
    flat_list = list()
    for page_no in range(0, max_no):
        try:
            new_url = ".".join(url.split(".")[:-2]) + "." + str(page_no) + ".html"
            # print(f"New url: {new_url}")
            resp = get_request(new_url)
            soup = BeautifulSoup(resp.content , 'lxml')
            length = count_announcements(soup)
            flat_list += get_announcements_from_page(soup)
            # print(f"Page {page_no} processed successfully: {length} flats")
            time.sleep(random.uniform(0, 2))
            page_no += 1
            # if page_no  > 220:
            #     return flat_list
        except:
            print(f"{page_no} pages successfully scanned. Script ended because of error.")
            return flat_list
    return flat_list

def extract_dates(string):
    return re.findall(r'\d{2}.\d{2}.\d{4}', string)

def get_request(url):
    # http://www.useragentstring.com/pages/useragentstring.php?name=Chrome
    headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/70.0.3538.77 Safari/537.36'}
    r = requests.get(url, headers)
    return r

# %% [markdown]
# # Flat class

# %%
class Flat:
    
    def __init__(self, title, url, address, size, price, room_no, date_of_availability):
        self.title = title
        self.url = url
        self.address = address
        self.size = size
        self.price = price
        self.room_no = room_no
        self.date_of_availability = date_of_availability
        
    def __str__(self):
        return f'''
        Title: {self.title}
        URL: {self.url}
        Address: {self.address}
        Size: {self.size}
        Price: {self.price}
        Number of rooms: {self.room_no}
        Date of availability: {self.date_of_availability}
        '''

# %% [markdown]
# # Individual class for each platforn

# %%
class Flat_portal:

    def __init__(self, url, max_no):
        self.url = url
        self.flat_pages = iterate_through_pages(url, max_no = max_no)
        self.flats = []
        for page in self.flat_pages:
            flat_page = get_request(page[1])
            flat_soup = BeautifulSoup(flat_page.content, 'lxml')
            self.flats.append(self.extract_flat_data(flat_soup, page[0], page[1]))
            
    def __str__(self):
        return f'''
        Url: {url}
        '''

# %%
class WG_gesucht(Flat_portal):
    
    def extract_flat_data(self, flat_soup, title, url):
        headline_items = flat_soup.find_all("h2", class_ = "headline headline-key-facts")
        try:
            size = process_string(headline_items[0].text)
        except: 
            size = "unknown"
        try:
            price = process_string(headline_items[1].text)
        except:
            price = "unknown"
        try:
            room_no = process_string(headline_items[2].text)
        except:
            room_no = "unknown"

        try:
            address_string = flat_soup.find_all("a", attrs = { "style" : "line-height: 1.5em;font-weight: normal; color: #555; margin-bottom: 23px;"})[0].text
            address = process_string(address_string)
        except:
            address = "unknown"

        # Extract the date of availability
        try:
            data = []
            for nested_soup in flat_soup.find_all("div", class_ = "col-sm-3"):
                    data +=  nested_soup.find_all("p", attrs = { "style" : "line-height: 2em;"})
            date_of_availability = extract_dates(data[0].text)[0]
        except:
            date_of_availability = "unknown"
        
        # print(f"Address: {address}")
        # print(f"Size: {size}")
        # print(f"Price: {price}")
        # print(f"Number of Rooms: {room_no}")
        # print(f"Date of availability: {date_of_availability}")

        return Flat(
            title = title,
            url = url,
            address = address,
            size = size,
            price = price,
            room_no = room_no,
            date_of_availability = date_of_availability,
        )

# %%
class EbayKleinanzeigen(Flat_portal):
    # https://www.ebay-kleinanzeigen.de/s-auf-zeit-wg/95444/c199l7494r10
    pass

# %%
class Immowelt(Flat_portal):
    pass

# %%
class Immobilienscout24(Flat_portal):
    pass

# %%
class Wohnungsboerse(Flat_portal):
    pass
    # https://www.wohnungsboerse.net/Bayreuth/wohnen-auf-zeit

# %%
class MeineStadt(Flat_portal):
    pass
    # https://www.meinestadt.de/bayreuth/immobilien/wohnen-auf-zeit

# %%
class Immosuchmaschine(Flat_portal) :
    pass
    # https://www.immosuchmaschine.de/k/bayreuth/wohnen-auf-zeit

# %%
class Immonet(Flat_portal):
    pass
    # https://www.immonet.de/bayern/bayreuth-moebliertes-wohnen.html

# %% [markdown]
# # Running area

# %%
wg_gesucht = WG_gesucht(url = "https://www.wg-gesucht.de/1-zimmer-wohnungen-und-wohnungen-und-haeuser-in-Bayreuth.6.1+2+3.1.0.html" , max_no = 3)

# %%
immowelt = Immowelt(url = "https://www.immowelt.de/liste/bayreuth/wohnungen/mieten")

# %%
immoscout = Immobilienscout24(url = "https://www.immobilienscout24.de/Suche/radius/wohnung-mieten?centerofsearchaddress=Bayreuth;95444;;;;&geocoordinates=49.94349;11.57631;5.0")

# %%
for flat in (wg_gesucht.flats):
    print(flat)
# Out:
#         Title: Nach Sanierung: WG-geeignete 2-Zimmer-DG Whg. mit Gemeinschaftsgarten
#         URL: https://www.wg-gesucht.de/wohnungen-in-Bayreuth-Birken.9001917.html
#         Address: Pottensteinerstraße 00 95447 Bayreuth Birken
#         Size: 32m²
#         Price: 460€
#         Number of rooms: 2
#         Date of availability: 01.02.2022
#
#
#         Title: Nach Sanierung: WG-geeignete 2-Zimmer-Whg. mit Gemeinschaftsgarten
#         URL: https://www.wg-gesucht.de/wohnungen-in-Bayreuth-Birken.8922122.html
#         Address: Pottensteinerstraße 00 95447 Bayreuth Birken
#         Size: 50m²
#         Price: 730€
#         Number of rooms: 2
#         Date of availability: 01.02.2022
#
#
#         Title: KURZFRISTIGE 2,5 Zimmerwohnung (WG-geeignet)
#         URL: https://www.wg-gesucht.de/wohnungen-in-Bayreuth-Altstadt.9097855.html
#         Address: Hohenzollernring 69 95444 Bayreuth Altstadt
#         Size: 95m²
#         Price: 850€
#         Number of rooms: 2
#         Date of availability: 01.02.2022
#
#
#         Title: Komplette 3er WG - Frei ab 01.04.22
#         URL: https://www.wg-gesucht.de/wohnungen-in-Bayreuth-City.9143165.html
#         Address: Kolpingstraße 95444 Bayreuth City
#         Size: 90m²
#         Price: 950€
#         Number of rooms: 3
#         Date of availability: 01.04.2022
#
#
#         Title: Modernes möbliertes Studenten-Appartement 28 m² mit Balkon (Campus-Jakobshöhe) Nachmieter gesucht
#         URL: https://www.wg-gesucht.de/1-zimmer-wohnungen-in-Bayreuth-Altstadt.9140373.html
#         Address: Jakobstraße 39a 95447 Bayreuth Altstadt
#         Size: 28m²
#         Price: 490€
#         Number of rooms: unknown
#         Date of availability: 01.04.2022
#
#
#         Title: (Verfügbar 1-24 Monate) - Apartment mit Sonnenterrasse in Bayreuth
#         URL: https://www.wg-gesucht.de/1-zimmer-wohnungen-und-wohnungen-und-haeuser-in-Bayreuth.6.1+2+3.1.0.html?asset_id=9023414&pu=12685206&sort_column=1&sort_order=0
#         Address: unknown
#         Size: unknown
#         Price: unknown
#         Number of rooms: unknown
#         Date of availability: unknown
#
#
#         Title: Studentenwohnung in der nähe der Universität
#         URL: https://www.wg-gesucht.de/wohnungen-in-Bayreuth-Birken.9140254.html
#         Address: Emil-Warburg weg 19/21 95447 Bayreuth Birken
#         Size: 15m²
#         Price: 274€
#         Number of rooms: 1
#         Date of availability: 01.03.2022
#
#
#         Title: Modernes möbliertes Studenten-Appartement 28 m² mit Balkon (Campus-Jakobshöhe)
#         URL: https://www.wg-gesucht.de/1-zimmer-wohnungen-in-Bayreuth-Altstadt.9039390.html
#         Address: Jakobstraße 39A 95447 Bayreuth Altstadt
#         Size: 28m²
#         Price: 490€
#         Number of rooms: unknown
#         Date of availability: 25.01.2022
#
#
#         Title: Nachmieter für 2-Zimmer-Wohnung mit schönem Ausblick gesucht
#         URL: https://www.wg-gesucht.de/wohnungen-in-Bayreuth-Glocke.9134418.html
#         Address: Ludwig-Thoma-Str. 66 95447 Bayreuth Glocke
#         Size: 30m²
#         Price: 514€
#         Number of rooms: 2
#         Date of availability: 01.04.2022
#
#
#         Title: Zentral gelegenes, möbliertes Apartment bei Uni Apart
#         URL: https://www.wg-gesucht.de/1-zimmer-wohnungen-in-Bayreuth-City.9133617.html
#         Address: Jospehsplatz 3 95444 Bayreuth City
#         Size: 22m²
#         Price: 424€
#         Number of rooms: unknown
#         Date of availability: 01.03.2022
#
#
#         Title: 5 Zimmerwohnung mit Balkon WG geignet für 3 Personen
#         URL: https://www.wg-gesucht.de/wohnungen-in-Bayreuth-City.9133100.html
#         Address: Carl Schiller Str. 7 95444 Bayreuth City
#         Size: 80m²
#         Price: 790€
#         Number of rooms: 4
#         Date of availability: 01.05.2022
#
#
#         Title: Uninähe - 1 Zimmer-Wohnung für Wochenendheimfahrer
#         URL: https://www.wg-gesucht.de/1-zimmer-wohnungen-in-Bayreuth-Birken.9123427.html
#         Address: Albert-Schweitzer-Str. 18 95447 Bayreuth Birken
#         Size: 20m²
#         Price: 320€
#         Number of rooms: unknown
#         Date of availability: 01.02.2022
#
#
#         Title: **Achtung Studenten, Azubis**Günstige 2-Zimmer-Wohnung zu vermieten! Nähe Uni!
#         URL: https://www.wg-gesucht.de/wohnungen-in-Bayreuth-Altstadt.7245287.html
#         Address: Robert-Koch-Str. 5 95447 Bayreuth Altstadt
#         Size: 37m²
#         Price: 400€
#         Number of rooms: 2
#         Date of availability: 01.02.2022
#
#
#         Title: möbliertes Zimmer mit Bad
#         URL: https://www.wg-gesucht.de/1-zimmer-wohnungen-in-Bayreuth-Bischofsgrun.3638149.html
#         Address: Göhren 2 95493 Bayreuth Bischofsgrün
#         Size: 20m²
#         Price: 400€
#         Number of rooms: unknown
#         Date of availability: 04.02.2022
#
#
#         Title: 2-Zimmer-Wohnung im Zentrum als 2er-WG geeignet, 48qm inkl. Heizung und Strom
#         URL: https://www.wg-gesucht.de/wohnungen-in-Bayreuth.8965411.html
#         Address: Kolpingstraße 3 95444 Bayreuth
#         Size: 48m²
#         Price: 550€
#         Number of rooms: 2
#         Date of availability: 01.02.2022
#
#
#         Title: Zwischenmiete: 1-Zimmer Apartment in sehr guter Lage für 3 oder 6 Monate
#         URL: https://www.wg-gesucht.de/1-zimmer-wohnungen-in-Bayreuth-Birken.9125255.html
#         Address: Robert Koch Straße 15 95447 Bayreuth Birken
#         Size: 21m²
#         Price: 390€
#         Number of rooms: unknown
#         Date of availability: 01.03.2022
#
#
#         Title: Wohnung (Umland v. Bayreuth)
#         URL: https://www.wg-gesucht.de/wohnungen-in-Bayreuth-City.8919521.html
#         Address: Wadendorf 95515 Bayreuth City
#         Size: 75m²
#         Price: 590€
#         Number of rooms: 2
#         Date of availability: 01.02.2022
#
#
#         Title: Zentrales 1-Zimmer- Apartment möbliert
#         URL: https://www.wg-gesucht.de/1-zimmer-wohnungen-in-Bayreuth-Zentrum.9119360.html
#         Address: Rathstraße 2 95444 Bayreuth Zentrum
#         Size: 20m²
#         Price: 290€
#         Number of rooms: unknown
#         Date of availability: 01.02.2022
#
#
#         Title: 4 Zimmerwohnung / 3 Schlafzimmer / Balkon / Hofgarten / Uninähe / Möbliert
#         URL: https://www.wg-gesucht.de/wohnungen-in-Bayreuth-City.9120268.html
#         Address: Cosima-Wagner-Straße 95444 Bayreuth City
#         Size: 116m²
#         Price: 1280€
#         Number of rooms: 4
#         Date of availability: 18.01.2022
#
#
#         Title: Möblierte Wohnung mit Terrasse und Garten in Uninähe
#         URL: https://www.wg-gesucht.de/wohnungen-in-Bayreuth-Oberkonnersreuth.9098171.html
#         Address: Albert-Einstein Ring 37 95448 Bayreuth Oberkonnersreuth
#         Size: 40m²
#         Price: 588€
#         Number of rooms: 2
#         Date of availability: 01.03.2022
#
#
#         Title: NUR für WOCHENENDHEIMFAHRER: Möbliertes Dachgeschoss mit Küchenzeile, seperates Waschbecken und WC, 320,00 Euro
#         URL: https://www.wg-gesucht.de/wohnungen-in-Bayreuth-Altstadt.8479565.html
#         Address: Stifterweg 12 95447 Bayreuth Altstadt
#         Size: 30m²
#         Price: 320€
#         Number of rooms: 1
#         Date of availability: 01.02.2022
#
#
#         Title: Ruhige 1 1/2 Zimmer
#         URL: https://www.wg-gesucht.de/1-zimmer-wohnungen-in-Bayreuth-City.7073779.html
#         Address: Wirthstr. 4 95445 Bayreuth City
#         Size: 36m²
#         Price: 520€
#         Number of rooms: unknown
#         Date of availability: 01.03.2022
#
#
#         Title: 1-Zimmer-Wohnung in Bayreuth innenstadtnah
#         URL: https://www.wg-gesucht.de/1-zimmer-wohnungen-in-Bayreuth-City.9084087.html
#         Address: Munckerstraße 15 95444 Bayreuth City
#         Size: 19m²
#         Price: 320€
#         Number of rooms: unknown
#         Date of availability: 17.01.2022
#
#
#         Title: Altbauwohnung mit Balkon zur Zwischenmiete
#         URL: https://www.wg-gesucht.de/1-zimmer-wohnungen-in-Bayreuth-Gartenstadt.9105880.html
#         Address: Friedrich-von-Schiller-Straße 95444 Bayreuth Gartenstadt
#         Size: 35m²
#         Price: 425€
#         Number of rooms: unknown
#         Date of availability: 15.02.2022
#
#
#         Title: 2-Zimmer Wohnung in Bayreuth - Zwischen Bahnhof und City - WG geeignet
#         URL: https://www.wg-gesucht.de/wohnungen-in-Bayreuth-City.9105935.html
#         Address: Bahnhofstraße 0 95444 Bayreuth City
#         Size: 55m²
#         Price: 750€
#         Number of rooms: 2
#         Date of availability: 01.03.2022
#
#
#         Title: Helle Dachgeschosswohnung mit Dachgaube, unmittelbare Uninähe, vollmöbliert
#         URL: https://www.wg-gesucht.de/1-zimmer-wohnungen-in-Bayreuth-Frankengut.5120106.html
#         Address: Frankengutstraße 10 95447 Bayreuth Frankengut
#         Size: 30m²
#         Price: 450€
#         Number of rooms: unknown
#         Date of availability: 01.04.2022
#
#
#         Title: (Verfügbar 1-24 Monate) - Studio mit idealer Lage in Lage in Bayreuth
#         URL: https://www.wg-gesucht.de/1-zimmer-wohnungen-und-wohnungen-und-haeuser-in-Bayreuth.6.1+2+3.1.0.html?asset_id=9023413&pu=12685206&sort_column=1&sort_order=0
#         Address: unknown
#         Size: unknown
#         Price: unknown
#         Number of rooms: unknown
#         Date of availability: unknown
#
#
#         Title: Renovierte 3-Zimmer-Wohnung mit Balkon und Einbauküche in Bayreuth
#         URL: https://www.wg-gesucht.de/wohnungen-in-Bayreuth-Bayreuth.9103264.html
#         Address: Riedingerstraße 95448 Bayreuth Bayreuth
#         Size: 90m²
#         Price: 830€
#         Number of rooms: 3
#         Date of availability: 01.02.2022
#
#
#         Title: Wohnung zur WG
#         URL: https://www.wg-gesucht.de/wohnungen-in-Bayreuth-Gartenstadt.9085900.html
#         Address: Munckerstraße 2 95444 Bayreuth Gartenstadt
#         Size: 116m²
#         Price: 1375€
#         Number of rooms: 3
#         Date of availability: 01.04.2022
#
#
#         Title: Nachmieter gesucht ab 01.02.22
#         URL: https://www.wg-gesucht.de/1-zimmer-wohnungen-in-Bayreuth-Laineck.9081456.html
#         Address: Danziger Straße 3 95448 Bayreuth Laineck
#         Size: 23m²
#         Price: 355€
#         Number of rooms: unknown
#         Date of availability: 01.02.2022
#
#
#         Title: TOP ANGEBOT FÜR ANGEHÖRIGE DIE IHRE FAMILIE IN BAYREUTH BESUCHEN
#         URL: https://www.wg-gesucht.de/1-zimmer-wohnungen-in-Bayreuth-Altstadt.9004491.html
#         Address: Stifterweg 12 95447 Bayreuth Altstadt
#         Size: 30m²
#         Price: 35€
#         Number of rooms: unknown
#         Date of availability: 20.01.2022
#
#
#         Title: TOP Angebot FÜR ANGEHÖRIGE; DIE IHRE FAMILIE IN BAYREUTH BESUCHEN
#         URL: https://www.wg-gesucht.de/1-zimmer-wohnungen-in-Bayreuth-Altstadt.9004487.html
#         Address: Stifterweg 12 95447 Bayreuth Altstadt
#         Size: 30m²
#         Price: 35€
#         Number of rooms: unknown
#         Date of availability: 03.11.2021
#
#
#         Title: Couch in 2 Zimmer Wohnung zeitweise zum Übernachten
#         URL: https://www.wg-gesucht.de/wohnungen-in-Bayreuth-Meyernberg.8943614.html
#         Address: Kopernikusring 71 95447 Bayreuth Meyernberg
#         Size: 80m²
#         Price: 20€
#         Number of rooms: 2
#         Date of availability: 05.10.2021
#
#
#         Title: Schöne, 120qm, teilmöblierte 4-Zimmer-Wohnung mit Terrasse zu vermieten
#         URL: https://www.wg-gesucht.de/wohnungen-in-Bayreuth-Altstadt.9128505.html
#         Address: Spitzwegstr. 95447 Bayreuth Altstadt
#         Size: unknown
#         Price: unknown
#         Number of rooms: unknown
#         Date of availability: unknown
#
#
#         Title: Nachmieter für schöne Dachgeschosswohnung zu Zweit gesucht
#         URL: https://www.wg-gesucht.de/wohnungen-in-Bayreuth-Altstadt.9116133.html
#         Address: Jakobstraße, 95447 Bayreuth Altstadt
#         Size: unknown
#         Price: unknown
#         Number of rooms: unknown
#         Date of availability: unknown
#
#
#         Title: Wohnung im Studentenwohnheim mit 2 Zimmern
#         URL: https://www.wg-gesucht.de/wohnungen-in-Bayreuth-Laineck.8791714.html
#         Address: Danzigerstraße 95448 Bayreuth Laineck
#         Size: unknown
#         Price: unknown
#         Number of rooms: unknown
#         Date of availability: unknown
#
#
#         Title: Wohnung zum Vermieten
#         URL: https://www.wg-gesucht.de/wohnungen-in-Bayreuth-City.8111794.html
#         Address: Josephsplatz 95444 Bayreuth City
#         Size: unknown
#         Price: unknown
#         Number of rooms: unknown
#         Date of availability: unknown
#
#
#         Title: ***Achtung Studenten/Azubis***Günstiges, neu renoviertes 1-Zimmer Appartements zu vermieten! Nähe Uni!
#         URL: https://www.wg-gesucht.de/1-zimmer-wohnungen-in-Bayreuth-Altstadt.6966280.html
#         Address: Robert-Koch-Str. 95447 Bayreuth Altstadt
#         Size: unknown
#         Price: unknown
#         Number of rooms: unknown
#         Date of availability: unknown
#
#
#         Title: 1½ Zimmer Galeriewohnung mit Dachterrasse
#         URL: https://www.wg-gesucht.de/1-zimmer-wohnungen-in-Bayreuth-Roter-Hugel.9133718.html
#         Address: unknown
#         Size: unknown
#         Price: unknown
#         Number of rooms: unknown
#         Date of availability: unknown
#
#
#         Title: möbliertes Apartment im Studentenwohnheim YOUNIQ
#         URL: https://www.wg-gesucht.de/1-zimmer-wohnungen-in-Bayreuth-Altstadt.9141089.html
#         Address: unknown
#         Size: unknown
#         Price: unknown
#         Number of rooms: unknown
#         Date of availability: unknown
#
#
#         Title: Untermiete 1-Zimmer-Appartment in ruhiger, schöner Lage
#         URL: https://www.wg-gesucht.de/1-zimmer-wohnungen-in-Bayreuth-Altstadt.9101532.html
#         Address: unknown
#         Size: unknown
#         Price: unknown
#         Number of rooms: unknown
#         Date of availability: unknown
#
#
#         Title: 2 Schlafzimmer Wohnung
#         URL: https://www.wg-gesucht.de/wohnungen-in-Bayreuth-City.9137952.html
#         Address: unknown
#         Size: unknown
#         Price: unknown
#         Number of rooms: unknown
#         Date of availability: unknown
#
#
#         Title: (Verfügbar 1-24 Monate) - Apartment Suite
#         URL: https://www.wg-gesucht.de/1-zimmer-wohnungen-und-wohnungen-und-haeuser-in-Bayreuth.6.1+2+3.1.0.html?asset_id=9073730&pu=12685206&sort_column=1&sort_order=0
#         Address: unknown
#         Size: unknown
#         Price: unknown
#         Number of rooms: unknown
#         Date of availability: unknown
#
#
#         Title: Renovierte 3-Zimmer-Wohnung mit Balkon und Einbauküche in Bayreuth
#         URL: https://www.wg-gesucht.de/wohnungen-in-Bayreuth-Industriegebiet.9046491.html
#         Address: unknown
#         Size: unknown
#         Price: unknown
#         Number of rooms: unknown
#         Date of availability: unknown
#
#
#         Title: Möbiliert Wohnung ab sofort zu vermieten
#         URL: https://www.wg-gesucht.de/wohnungen-in-Bayreuth-Altstadt.9084819.html
#         Address: unknown
#         Size: unknown
#         Price: unknown
#         Number of rooms: unknown
#         Date of availability: unknown
#
#
#         Title: Nachmieter zum 01.03. gesucht für Apartment im UniApart Bayreuth
#         URL: https://www.wg-gesucht.de/1-zimmer-wohnungen-in-Bayreuth-City.9125112.html
#         Address: unknown
#         Size: unknown
#         Price: unknown
#         Number of rooms: unknown
#         Date of availability: unknown
#
#
#         Title: Renovierte 1-Zimmer-Wohnung in Bayreuth City
#         URL: https://www.wg-gesucht.de/1-zimmer-wohnungen-in-Bayreuth-City.9126585.html
#         Address: unknown
#         Size: unknown
#         Price: unknown
#         Number of rooms: unknown
#         Date of availability: unknown
#
#
#         Title: Helle große Wohnung mit Blick in die Ferne
#         URL: https://www.wg-gesucht.de/wohnungen-in-Bayreuth-Aichig.8935264.html
#         Address: unknown
#         Size: unknown
#         Price: unknown
#         Number of rooms: unknown
#         Date of availability: unknown
#
#
#         Title: Untermiete 1-Zimmer inkl. Parkplatz Febr.-Aug.
#         URL: https://www.wg-gesucht.de/1-zimmer-wohnungen-in-Bayreuth-Roehrensee.9117040.html
#         Address: unknown
#         Size: unknown
#         Price: unknown
#         Number of rooms: unknown
#         Date of availability: unknown
#
#
#         Title: Sehr schöne, sonnige 2-Zimmerwohnung, ideal für Studenten
#         URL: https://www.wg-gesucht.de/wohnungen-in-Bayreuth-Hammerstatt.2906420.html
#         Address: unknown
#         Size: unknown
#         Price: unknown
#         Number of rooms: unknown
#         Date of availability: unknown
#
#
#         Title: *** MODERNES APARTMENT VERFÜGBAR ***
#         URL: https://www.wg-gesucht.de/1-zimmer-wohnungen-in-Bayreuth-Gartenstadt.9080885.html
#         Address: unknown
#         Size: unknown
#         Price: unknown
#         Number of rooms: unknown
#         Date of availability: unknown
#
#
#         Title: Grosse 4 Zimmerwohnung, Küche und Balkon
#         URL: https://www.wg-gesucht.de/wohnungen-in-Bayreuth-City.9063544.html
#         Address: unknown
#         Size: unknown
#         Price: unknown
#         Number of rooms: unknown
#         Date of availability: unknown
#
#
#         Title: Nachmieter gesucht zum 01.03.2022 im UniApart Bayreuth
#         URL: https://www.wg-gesucht.de/1-zimmer-wohnungen-in-Bayreuth-City.9111319.html
#         Address: unknown
#         Size: unknown
#         Price: unknown
#         Number of rooms: unknown
#         Date of availability: unknown
#
#
#         Title: **** Bayreuth – Schöne, helle und gepflegte 1-Zimmer-Wohnung ****
#         URL: https://www.wg-gesucht.de/1-zimmer-wohnungen-in-Bayreuth-Oberkonnersreuth.9090808.html
#         Address: unknown
#         Size: unknown
#         Price: unknown
#         Number of rooms: unknown
#         Date of availability: unknown
#
#
#         Title: Helle 2-Zimmer-Dachgeschosswohnung mit kleinem Balkon, Einbauküche und renoviertem Badezimmer
#         URL: https://www.wg-gesucht.de/wohnungen-in-Bayreuth-Kreuz.9074902.html
#         Address: unknown
#         Size: unknown
#         Price: unknown
#         Number of rooms: unknown
#         Date of availability: unknown
#
#
#         Title: Möbilierte 1-Zimmer-Wohnung im Zentrum zur Untermiete
#         URL: https://www.wg-gesucht.de/1-zimmer-wohnungen-in-Bayreuth-City.7846526.html
#         Address: unknown
#         Size: unknown
#         Price: unknown
#         Number of rooms: unknown
#         Date of availability: unknown
#
#
#         Title: 1 Zimmer Appt mit TG Stellplatz nähe Uni
#         URL: https://www.wg-gesucht.de/1-zimmer-wohnungen-in-Bayreuth-Oberkonnersreuth.8976406.html
#         Address: unknown
#         Size: unknown
#         Price: unknown
#         Number of rooms: unknown
#         Date of availability: unknown
#
#
#         Title: Schöne möbliertes 1-Zimmer Wohnung zur Zwischenmiete
#         URL: https://www.wg-gesucht.de/1-zimmer-wohnungen-in-Bayreuth-Bayreuth.9053748.html
#         Address: unknown
#         Size: unknown
#         Price: unknown
#         Number of rooms: unknown
#         Date of availability: unknown
#
#
#         Title: 1-Zimmer-Whg - EBK, Kelleranteil, Balkon, Badewanne, Parkplatz
#         URL: https://www.wg-gesucht.de/1-zimmer-wohnungen-in-Bayreuth-St-Georgen.6776123.html
#         Address: unknown
#         Size: unknown
#         Price: unknown
#         Number of rooms: unknown
#         Date of availability: unknown
#
#
#         Title: WG-taugliche Wohnung hell und ruhige Lage
#         URL: https://www.wg-gesucht.de/wohnungen-in-Bayreuth-Altstadt.9026236.html
#         Address: unknown
#         Size: unknown
#         Price: unknown
#         Number of rooms: unknown
#         Date of availability: unknown
#
#
#         Title: Nachmieter für mobilierte Wohnung im Youniq (Altstadt) gesucht
#         URL: https://www.wg-gesucht.de/1-zimmer-wohnungen-in-Bayreuth-Altstadt.9064098.html
#         Address: unknown
#         Size: unknown
#         Price: unknown
#         Number of rooms: unknown
#         Date of availability: unknown
#
#
#         Title: Nachmieter für mobilierte Wohnung im Youniq (Altstadt) gesucht
#         URL: https://www.wg-gesucht.de/1-zimmer-wohnungen-in-Bayreuth-Altstadt.9080437.html
#         Address: unknown
#         Size: unknown
#         Price: unknown
#         Number of rooms: unknown
#         Date of availability: unknown
#
#
#         Title: Apartment mit TG Stellplatz am Hofgarten
#         URL: https://www.wg-gesucht.de/1-zimmer-wohnungen-in-Bayreuth-City.9041841.html
#         Address: unknown
#         Size: unknown
#         Price: unknown
#         Number of rooms: unknown
#         Date of availability: unknown
